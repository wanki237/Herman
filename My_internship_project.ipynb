# %%
import pandas as pd
df =pd.read_csv(r"C:\Users\USER\Desktop\za\CSS\heart_disease_uci.csv")
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
#num=heart disease present
#chol=cholesterol
#cp=Chest pain
#trestbps=Resting blood pressure
#thalch=Maximum heart rate
#restecg=Resting Electrographic results
#exang=Health Information Exchange
#oldpeak=
#ca=Cardiac Arrest
#thal=thalassemia(An inherited blood disease )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
missing_vallues=df.isnull().sum()
missing_vallues
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %%
#filling dupplicates
import numpy as np
df.replace('?', np.nan, inplace=True)
df['chol'] = df['chol'].replace(0, np.nan)
df['thal'] = df['thal'].fillna(df['thal'].mode()[0])
df['ca'] = df['ca'].fillna(df['ca'].mode()[0])
df['slope'] = df['slope'].fillna(df['slope'].mode()[0])
df['oldpeak'] = df['oldpeak'].fillna(df['oldpeak'].mode()[0])
df['exang'] = df['exang'].fillna(df['exang'].mode()[0])
df['thalch'] = df['thalch'].fillna(df['thalch'].mode()[0])
df['restecg'] = df['restecg'].fillna(df['restecg'].mode()[0])
df['fbs'] = df['fbs'].fillna(df['fbs'].mode()[0])
df['chol'] = df['chol'].fillna(df['chol'].mode()[0])
df['trestbps'] = df['trestbps'].fillna(df['trestbps'].mode()[0])
df
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6156\3099571306.py:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['exang'] = df['exang'].fillna(df['exang'].mode()[0])
# C:\Users\USER\AppData\Local\Temp\ipykernel_6156\3099571306.py:12: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['fbs'] = df['fbs'].fillna(df['fbs'].mode()[0])
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# ...

# %%
#Cheching if missing values have being filled
missing_vallues=df.isnull().sum()
missing_vallues
# Out:
# id          0
# age         0
# sex         0
# dataset     0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalch      0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
#remove duplicate 
df_cleaned=df.drop_duplicates()
df_cleaned
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina     120.0  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic     120.0  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
#dropping some  with important missing vllues columns
df.drop(['chol','trestbps'],axis=1)
# Out:
#       id  age     sex        dataset               cp    fbs  \
# 0      1   63    Male      Cleveland   typical angina   True
# 1      2   67    Male      Cleveland     asymptomatic  False
# 2      3   67    Male      Cleveland     asymptomatic  False
# 3      4   37    Male      Cleveland      non-anginal  False
# 4      5   41  Female      Cleveland  atypical angina  False
# ..   ...  ...     ...            ...              ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic   True
# 916  917   62    Male  VA Long Beach   typical angina  False
# 917  918   55    Male  VA Long Beach     asymptomatic   True
# 918  919   58    Male  VA Long Beach     asymptomatic   True
# 919  920   62    Male  VA Long Beach  atypical angina  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# 0      lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1      lv hypertrophy   108.0   True      1.5         flat  3.0
# ...

# %%
#find outliers
df.describe()[['age','thalch']]
# Out:
#               age      thalch
# count  920.000000  920.000000
# mean    53.510870  138.290217
# std      9.424685   25.311498
# min     28.000000   60.000000
# 25%     47.000000  120.000000
# 50%     54.000000  140.000000
# 75%     60.000000  156.000000
# max     77.000000  202.000000

# %%
#remove outliers
def remove_outliers(df, numeric_features):

    numeric_features=['chol','trestbps','thalch','oldpeak','ca']


    df=remove_outliers(df, numeric_features)

df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina     120.0  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic     120.0  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
# #cleaning data
# df['chol']=pd.to_numeric(df['chol'],errors='coerce')
# df['num']=df['num'].astype(str)
# df['num']
# df['chol']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="num", hue="sex", data=df)
plt.title("num count by sex")
plt.xlabel("sex")
plt.ylabel("Count")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="num", hue="cp", data=df)
plt.title("num count by cp")
plt.xlabel("cp")
plt.ylabel("Count")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="num", hue="thal", data=df)
plt.title("num count by thal")
plt.xlabel("thal")
plt.ylabel("Count")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="num", hue="cp", data=df)
plt.title("num count by cp")
plt.xlabel("cp")
plt.ylabel("Count")
plt.show()
#Typical Agina=this is a chest pain that happens during physical activities and is caused by reduced blood flow to the heart
#Atypical Agina = this is chest pain that happens without physical activities ie at rest
#Non aginal chest pain = it is not caused by chest pain but by otherissues like muscle strain, anxiety etc
#Asymptomatic = here, a person has reduced blook flow to the heart but feels no chest pain

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="num", hue="cp", data=df)
plt.title("num count by cp")
plt.xlabel("num")
plt.ylabel("cp")
plt.show()
#Typical Agina=this is a chest pain that happens during physical activities and is caused by reduced blood flow to the heart
#Atypical Agina = this is chest pain that happens without physical activities ie at rest
#Non aginal chest pain = it is not caused by chest pain but by otherissues like muscle strain, anxiety etc
#Asymptomatic = here, a person has reduced blook flow to the heart but feels no chest pain

# %%
#num vs cholesterol
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
plt.ylabel("chol")
df.groupby('num')['chol'].mean().plot(kind='bar',alpha=0.7)
# Out:
# <Axes: xlabel='num', ylabel='chol'>

# %%
#num vs cholesterol
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
plt.ylabel("trestbps")
df.groupby('num')['trestbps'].mean().plot(kind='bar',alpha=0.7)
# Out:
# <Axes: xlabel='num', ylabel='trestbps'>

# %%
1 heart desease present vs chest pain
# Out:
#   Cell In[643], line 1
#     1 heart desease present vs chest pain
#       ^
# SyntaxError: invalid syntax
